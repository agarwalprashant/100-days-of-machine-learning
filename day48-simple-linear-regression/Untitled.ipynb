# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('placement.csv')

# %%
df.shape
# Out:
# (200, 2)

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cgpa     200 non-null    float64
#  1   package  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train.shape
# Out:
# (160, 1)

# %%
y_train.shape
# Out:
# (160,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
d = X_train.values.reshape(-1,1)
t = y_train.values.reshape(-1,1)

# %%
lr.fit(d,t)
# Out:
# LinearRegression()

# %%
X_test.shape
# Out:
# (40, 1)

# %%
lr.predict(X_test)
# Out:
# /Users/p0a0221/Downloads/campusx-notes/100-days-of-machine-learning/my_env/lib/python3.12/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# array([[3.89111601],
#        [3.09324469],
#        [2.38464568],
#        [2.57434935],
#        [1.6537286 ],
#        [1.77647803],
#        [2.07219258],
#        [2.93143862],
#        [3.76278706],
#        [2.93701814],
#        [4.09197872],
#        [3.51170867],
#        [2.97049525],
#        [2.40138424],
#        [3.18809652],
#        [3.46707251],
#        [1.94386362],
#        [3.24389172],
#        [2.97607477],
#        [3.41685683],
#        [2.55761079],
#        [3.16577844],
#        [2.85890486],
#        [3.12114229],
#        [3.68467378],
#        [2.8700639 ],
#        [3.49497011],
#        [3.34432308],
#        [3.91901361],
#        [1.96060218],
#        [3.65119666],
#        [3.2104146 ],
#        [3.74046898],
#        [2.7863711 ],
#        [2.78079158],
#        [3.27178932],
#        [3.52844723],
#        [2.61340599],
#        [2.65804215],
#        [2.71383735]])

# %%
y_test
# Out:
# 112    4.10
# 29     3.49
# 182    2.08
# 199    2.33
# 193    1.94
# 85     1.48
# 10     1.86
# 54     3.09
# 115    4.21
# 35     2.87
# 12     3.65
# 92     4.00
# 13     2.89
# 126    2.60
# 174    2.99
# 2      3.25
# 44     1.86
# 3      3.67
# 113    2.37
# 14     3.42
# 23     2.48
# 25     3.65
# 6      2.60
# 134    2.83
# 165    4.08
# 173    2.56
# 45     3.58
# 65     3.81
# 48     4.09
# 122    2.01
# 178    3.63
# 64     2.92
# 9      3.51
# 57     1.94
# 78     2.21
# 71     3.34
# 128    3.34
# 176    3.23
# 131    2.01
# 53     2.61
# Name: package, dtype: float64

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
X,y = df.iloc[:,0:1],df.iloc[:,-1]

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train.shape
# Out:
# (160, 1)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57
# 85   4.79
# 10   5.32
# 54   6.86
# 115  8.35
# 35   6.87
# 12   8.94
# 92   7.90
# 13   6.93
# 126  5.91
# 174  7.32
# 2    7.82
# 44   5.09
# 3    7.42
# 113  6.94
# 14   7.73
# 23   6.19
# 25   7.28
# 6    6.73
# 134  7.20
# 165  8.21
# 173  6.75
# 45   7.87
# 65   7.60
# 48   8.63
# 122  5.12
# 178  8.15
# 64   7.36
# 9    8.31
# 57   6.60
# 78   6.59
# 71   7.47
# 128  7.93
# 176  6.29
# 131  6.37
# 53   6.47

# %%
X_test.iloc[0].values.reshape(1,1)
# Out:
# array([[8.58]])

# %%
X_test.shape
# Out:
# (40, 1)

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([3.89111601, 3.09324469, 2.38464568, 2.57434935, 1.6537286 ,
#        1.77647803, 2.07219258, 2.93143862, 3.76278706, 2.93701814,
#        4.09197872, 3.51170867, 2.97049525, 2.40138424, 3.18809652,
#        3.46707251, 1.94386362, 3.24389172, 2.97607477, 3.41685683,
#        2.55761079, 3.16577844, 2.85890486, 3.12114229, 3.68467378,
#        2.8700639 , 3.49497011, 3.34432308, 3.91901361, 1.96060218,
#        3.65119666, 3.2104146 , 3.74046898, 2.7863711 , 2.78079158,
#        3.27178932, 3.52844723, 2.61340599, 2.65804215, 2.71383735])

# %%
pd.DataFrame({
    "x_test":X_test['cgpa'],
    "y_test":y_test,
    "y_pred":y_pred
})
# Out:
#      x_test  y_test    y_pred
# 112    8.58    4.10  3.891116
# 29     7.15    3.49  3.093245
# 182    5.88    2.08  2.384646
# 199    6.22    2.33  2.574349
# 193    4.57    1.94  1.653729
# 85     4.79    1.48  1.776478
# 10     5.32    1.86  2.072193
# 54     6.86    3.09  2.931439
# 115    8.35    4.21  3.762787
# 35     6.87    2.87  2.937018
# 12     8.94    3.65  4.091979
# 92     7.90    4.00  3.511709
# 13     6.93    2.89  2.970495
# 126    5.91    2.60  2.401384
# 174    7.32    2.99  3.188097
# 2      7.82    3.25  3.467073
# 44     5.09    1.86  1.943864
# 3      7.42    3.67  3.243892
# 113    6.94    2.37  2.976075
# 14     7.73    3.42  3.416857
# 23     6.19    2.48  2.557611
# 25     7.28    3.65  3.165778
# 6      6.73    2.60  2.858905
# 134    7.20    2.83  3.121142
# 165    8.21    4.08  3.684674
# 173    6.75    2.56  2.870064
# 45     7.87    3.58  3.494970
# 65     7.60    3.81  3.344323
# 48     8.63    4.09  3.919014
# 122    5.12    2.01  1.960602
# 178    8.15    3.63  3.651197
# 64     7.36    2.92  3.210415
# 9      8.31    3.51  3.740469
# 57     6.60    1.94  2.786371
# 78     6.59    2.21  2.780792
# 71     7.47    3.34  3.271789
# 128    7.93    3.34  3.528447
# 176    6.29    3.23  2.613406
# 131    6.37    2.01  2.658042
# 53     6.47    2.61  2.713837

# %%
plt.scatter(df['cgpa'],df['package'])
# plt.plot(X_train,lr.predict(X_train),color='green')
plt.plot(X_test,lr.predict(X_test),'r-')


plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# /Users/p0a0221/Downloads/campusx-notes/100-days-of-machine-learning/my_env/lib/python3.12/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# Text(0, 0.5, 'Package(in lpa)')

# %%
m = lr.coef_

# %%
m
# Out:
# array([[0.55795197]])

# %%
b = lr.intercept_

# %%
b
# Out:
# array([-0.89611192])

# %%
# y = mx + b

m * 8.58 + b
# Out:
# array([3.89111601])

# %%
m * 6.94 + b
# Out:
# array([2.97607477])

# %%
m * 100 + b
# Out:
# array([54.89908542])

# %%
np.array(2)
# Out:
# array(2)
